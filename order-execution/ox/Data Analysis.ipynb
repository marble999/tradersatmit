# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

df = pd.read_csv('history.csv', header=None)

# %%
plt.figure(figsize=(20,12))
for i in range(9):
    df[i].plot(label=i)
plt.legend()

# %%
N = 100

data = np.genfromtxt('history.csv',delimiter=',')
returns = data[1:N,:] - data[:N-1,:]
corr = np.corrcoef(returns.T)

print(len(data))

sns.heatmap(corr, annot=True) ## use the median ---> highly likely to be correct
plt.show()

rho = np.median(corr.reshape(-1))
rho
# Out:
# 199
# 0.32531843021299534

# %%
X = returns[:,:2]
Y = returns[:,2:]
Y_pred = X * rho
Y-Y_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-5d1567410795> in <module>()
#       3 Y_pred = X * rho
#       4
# ----> 5 Y-Y_pred
#
# ValueError: operands could not be broadcast together with shapes (198,7) (198,2)

# %%
data = np.genfromtxt('history.csv',delimiter=',')
returns = data[1:,:] - data[:-1,:]

# %%
returns.mean(axis=0),
# Out:
# array([ 0.16727273,  0.03833333,  0.0619697 ,  0.06141414,  0.01641414,
#         0.12141414,  0.09217172, -0.0259596 , -0.02873737])
